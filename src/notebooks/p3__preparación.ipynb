# %% [markdown]
# ## 1- Cargamos los datos

# %%
import pandas as pd

data = pd.read_csv("../datasets/converted_data/customer_dataset.csv", sep = ",")
data
# Out:
#     fraudulent paymentMethodRegistrationFailure paymentMethodType  \
# 0        False                             True              card
# 1         True                             True           bitcoin
# 2        False                            False              card
# 3        False                            False              card
# 4         True                            False              card
# ..         ...                              ...               ...
# 618        NaN                              NaN               NaN
# 619        NaN                              NaN               NaN
# 620        NaN                              NaN               NaN
# 621        NaN                              NaN               NaN
# 622        NaN                              NaN               NaN
#
#            paymentMethodProvider     paymentMethodIssuer  transactionAmount  \
# 0                   JCB 16 digit    Citizens First Banks                 18
# 1                  VISA 16 digit            Solace Banks                 26
# 2                  VISA 16 digit          Vertex Bancorp                 45
# 3    Diners Club / Carte Blanche  His Majesty Bank Corp.                 23
# 4                     Mastercard          Vertex Bancorp                 43
# ..                           ...                     ...                ...
# 618                          NaN                     NaN                 25
# 619                          NaN                     NaN                 25
# 620                          NaN                     NaN                 25
# 621                          NaN                     NaN                 19
# 622                          NaN                     NaN                 27
#
#      transactionFailed  orderAmount orderState emailDomain emailProvider  \
# 0                False         18.0    pending         com         yahoo
# 1                False         26.0  fulfilled         com         yahoo
# 2                False         45.0  fulfilled         com         yahoo
# 3                False         23.0  fulfilled         com         yahoo
# 4                 True         43.0  fulfilled         com         other
# ..                 ...          ...        ...         ...           ...
# 618               True          NaN        NaN       weird         weird
# 619               True          NaN        NaN       weird         weird
# 620              False          NaN        NaN       weird         weird
# 621              False          NaN        NaN       weird         weird
# 622              False          NaN        NaN       weird         weird
#
#     customerIPAddressSimplified sameCity
# 0           only_numeric_digits      yes
# 1           only_numeric_digits       no
# 2            digits_and_letters       no
# 3            digits_and_letters       no
# 4           only_numeric_digits       no
# ..                          ...      ...
# 618         only_numeric_digits  unknown
# 619         only_numeric_digits  unknown
# 620         only_numeric_digits  unknown
# 621         only_numeric_digits  unknown
# 622         only_numeric_digits  unknown
#
# [623 rows x 13 columns]

# %%
from funpymodeling.exploratory import status

status(data)
# Out:
#                             variable  q_nan     p_nan  q_zeros   p_zeros  \
# 0                         fraudulent    455  0.730337      107  0.171750
# 1   paymentMethodRegistrationFailure    281  0.451043      302  0.484751
# 2                  paymentMethodType    281  0.451043        0  0.000000
# 3              paymentMethodProvider    281  0.451043        0  0.000000
# 4                paymentMethodIssuer    281  0.451043        0  0.000000
# 5                  transactionAmount      0  0.000000        0  0.000000
# 6                  transactionFailed      0  0.000000      455  0.730337
# 7                        orderAmount    145  0.232745        0  0.000000
# 8                         orderState    145  0.232745        0  0.000000
# 9                        emailDomain      0  0.000000        0  0.000000
# 10                     emailProvider      0  0.000000        0  0.000000
# 11       customerIPAddressSimplified      0  0.000000        0  0.000000
# 12                          sameCity      0  0.000000        0  0.000000
#
#     unique     type
# 0        2   object
# 1        2   object
# 2        4   object
# 3       10   object
# 4       20   object
# 5       67    int64
# 6        2     bool
# 7       67  float64
# 8        3   object
# 9        6   object
# 10       5   object
# 11       2   object
# 12       3   object

# %% [markdown]
# ## 2- Discretización

# %% [markdown]
# Hacemos una copia del dataframe __data__ para luego evaluar si los bins se guardan y leen correctamente.

# %%
probar = data.copy()

# %% [markdown]
# ### 2.1- Discretizar variables

# %% [markdown]
# #### `transactionAmount`

# %%
data["transactionAmount"], transactionAmount_bins = pd.qcut(data["transactionAmount"], q = 4, duplicates = "drop", retbins = True)

# %% [markdown]
# #### `orderAmount`

# %%
data["orderAmount"], orderAmount_bins = pd.qcut(data["orderAmount"], q = 5, duplicates = "drop", retbins = True)

# %% [markdown]
# ### 2.2 - Guardar bins y evaluarlos

# %% [markdown]
# Guardamos los bins generados por separado usando el modulo __pickle__.

# %%
import pickle

with open("../saved_bins/orderAmount_bins.pickle", "wb") as handle:
    pickle.dump(orderAmount_bins, handle, protocol = pickle.HIGHEST_PROTOCOL)

with open("../saved_bins/transactionAmount_bins.pickle", "wb") as handle:
    pickle.dump(transactionAmount_bins, handle, protocol = pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# Luego de guardarlos, los evaluamos para corroborar que se hayan guardado correctamente.

# %%
with open("../saved_bins/orderAmount_bins.pickle", "rb") as handle:
    new_orderAmount_bins = pickle.load(handle)

probar["orderAmount"] = pd.cut(probar["orderAmount"],
                                bins = new_orderAmount_bins,
                                include_lowest = True)

probar["orderAmount"].head(5)
# Out:
# 0    (9.999, 18.4]
# 1     (18.4, 30.0]
# 2     (39.0, 47.0]
# 3     (18.4, 30.0]
# 4     (39.0, 47.0]
# Name: orderAmount, dtype: category
# Categories (5, interval[float64, right]): [(9.999, 18.4] < (18.4, 30.0] < (30.0, 39.0] < (39.0, 47.0] < (47.0, 353.0]]

# %%
with open("../saved_bins/transactionAmount_bins.pickle", "rb") as handle:
    new_transactionAmount_bins = pickle.load(handle)

probar["transactionAmount"] = pd.cut(probar["transactionAmount"],
                                bins = new_transactionAmount_bins,
                                include_lowest = True)

probar["transactionAmount"].head(5)
# Out:
# 0    (9.999, 21.0]
# 1     (21.0, 34.0]
# 2     (34.0, 45.0]
# 3     (21.0, 34.0]
# 4     (34.0, 45.0]
# Name: transactionAmount, dtype: category
# Categories (4, interval[float64, right]): [(9.999, 21.0] < (21.0, 34.0] < (34.0, 45.0] < (45.0, 353.0]]

# %% [markdown]
# ## 3- Preparación de datos

# %% [markdown]
# ### 3.1- Interpretación valores

# %% [markdown]
# #### `paymentMethodIssuer`

# %%
data["paymentMethodIssuer"].value_counts()
# Out:
# paymentMethodIssuer
# Her Majesty Trust           43
# Vertex Bancorp              37
# Fountain Financial Inc.     35
# His Majesty Bank Corp.      33
# Bastion Banks               29
# Bulwark Trust Corp.         29
# Citizens First Banks        28
# Grand Credit Corporation    27
# Solace Banks                27
# Rose Bancshares             25
# B                            7
# e                            5
# c                            4
# r                            3
#                              2
# n                            2
# x                            2
# o                            2
# a                            1
# p                            1
# Name: count, dtype: int64

# %% [markdown]
# Como podemos observar varios métodos de pago raros, vamos a clasificarlos como _weird_.

# %%
weird_payment_method = ["B", "e", "c", "r", " ", "n", "x", "o", "a", "p"]

for payment_method in weird_payment_method:
    data["paymentMethodIssuer"] = data["paymentMethodIssuer"].replace(payment_method, "weird")

# %%
data["paymentMethodIssuer"].value_counts()
# Out:
# paymentMethodIssuer
# Her Majesty Trust           43
# Vertex Bancorp              37
# Fountain Financial Inc.     35
# His Majesty Bank Corp.      33
# Bastion Banks               29
# weird                       29
# Bulwark Trust Corp.         29
# Citizens First Banks        28
# Solace Banks                27
# Grand Credit Corporation    27
# Rose Bancshares             25
# Name: count, dtype: int64

# %% [markdown]
# #### `paymentMethodProvider`

# %%
data["paymentMethodProvider"].value_counts()
# Out:
# paymentMethodProvider
# JCB 16 digit                   65
# VISA 16 digit                  57
# Voyager                        36
# Diners Club / Carte Blanche    34
# Maestro                        32
# VISA 13 digit                  32
# Discover                       25
# American Express               22
# JCB 15 digit                   20
# Mastercard                     19
# Name: count, dtype: int64

# %% [markdown]
# #### `paymentMethodType`

# %%
data["paymentMethodType"].value_counts()
# Out:
# paymentMethodType
# card         242
# apple pay     36
# paypal        36
# bitcoin       28
# Name: count, dtype: int64

# %% [markdown]
# #### `fraudulent`

# %%
status(data).query("q_nan > 0")
# Out:
#                            variable  q_nan     p_nan  q_zeros   p_zeros  \
# 0                        fraudulent    455  0.730337      107  0.171750
# 1  paymentMethodRegistrationFailure    281  0.451043      302  0.484751
# 2                 paymentMethodType    281  0.451043        0  0.000000
# 3             paymentMethodProvider    281  0.451043        0  0.000000
# 4               paymentMethodIssuer    281  0.451043        0  0.000000
# 7                       orderAmount    145  0.232745        0  0.000000
# 8                        orderState    145  0.232745        0  0.000000
#
#    unique      type
# 0       2    object
# 1       2    object
# 2       4    object
# 3      10    object
# 4      11    object
# 7       5  category
# 8       3    object

# %% [markdown]
# Como la variable que vamos a predecir posee nulos, los vamos a reemplazar por _warning_.

# %%
data["fraudulent"] = data["fraudulent"].fillna(value = "warning")

# %%
data["fraudulent"].value_counts()
# Out:
# fraudulent
# warning    455
# False      107
# True        61
# Name: count, dtype: int64

# %% [markdown]
# Convertimos los valores a __str__ para asegurarnos de que no exista conflictos entre str y bool.

# %%
data["fraudulent"] = data["fraudulent"].astype("str")

# %% [markdown]
# Le asignamos un valor numérico a cada valor para hacer una especie de semáforo.
# - _False_ = Le asignamos el valor numérico _0_, representaría el __verde__ del semáforo.
# - _True_ = Le asignamos el valor numérico _1_, representaría el __rojo__ del semáforo.
# - _warning_ = Le asignamos el valor numérico _2_, representaría el __amarillo__ del semáforo.

# %%
class_map = {"False":0, "True":1, "warning":2}
data["fraudulent"] = data["fraudulent"].map(class_map)

# %%
data.head(5)
# Out:
#    fraudulent paymentMethodRegistrationFailure paymentMethodType  \
# 0           0                             True              card
# 1           1                             True           bitcoin
# 2           0                            False              card
# 3           0                            False              card
# 4           1                            False              card
#
#          paymentMethodProvider     paymentMethodIssuer transactionAmount  \
# 0                 JCB 16 digit    Citizens First Banks     (9.999, 21.0]
# 1                VISA 16 digit            Solace Banks      (21.0, 34.0]
# 2                VISA 16 digit          Vertex Bancorp      (34.0, 45.0]
# 3  Diners Club / Carte Blanche  His Majesty Bank Corp.      (21.0, 34.0]
# 4                   Mastercard          Vertex Bancorp      (34.0, 45.0]
#
#    transactionFailed    orderAmount orderState emailDomain emailProvider  \
# 0              False  (9.999, 18.4]    pending         com         yahoo
# 1              False   (18.4, 30.0]  fulfilled         com         yahoo
# 2              False   (39.0, 47.0]  fulfilled         com         yahoo
# 3              False   (18.4, 30.0]  fulfilled         com         yahoo
# 4               True   (39.0, 47.0]  fulfilled         com         other
#
#   customerIPAddressSimplified sameCity
# 0         only_numeric_digits      yes
# 1         only_numeric_digits       no
# 2          digits_and_letters       no
# 3          digits_and_letters       no
# 4         only_numeric_digits       no

# %% [markdown]
# ### 3.2- Tratamiento de nulos

# %% [markdown]
# Lo hacemos para nuestras columnas categóricas, y en este caso, la única columna categórica con datos faltantes es `orderAmount`

# %%
data["orderAmount"].value_counts()
# Out:
# orderAmount
# (30.0, 39.0]     98
# (39.0, 47.0]     97
# (9.999, 18.4]    96
# (18.4, 30.0]     96
# (47.0, 353.0]    91
# Name: count, dtype: int64

# %%
data["orderAmount"] = data["orderAmount"].cat.add_categories("desconocido")
data["orderAmount"] = data["orderAmount"].fillna(value="desconocido")

# %%
data["orderAmount"].value_counts()
# Out:
# orderAmount
# desconocido      145
# (30.0, 39.0]      98
# (39.0, 47.0]      97
# (9.999, 18.4]     96
# (18.4, 30.0]      96
# (47.0, 353.0]     91
# Name: count, dtype: int64

# %% [markdown]
# ## 4- One Hot Encoding

# %%
data_ohe = pd.get_dummies(data)
data_ohe
# Out:
#      fraudulent  transactionFailed  paymentMethodRegistrationFailure_False  \
# 0             0              False                                   False
# 1             1              False                                   False
# 2             0              False                                    True
# 3             0              False                                    True
# 4             1               True                                    True
# ..          ...                ...                                     ...
# 618           2               True                                   False
# 619           2               True                                   False
# 620           2              False                                   False
# 621           2              False                                   False
# 622           2              False                                   False
#
#      paymentMethodRegistrationFailure_True  paymentMethodType_apple pay  \
# 0                                     True                        False
# 1                                     True                        False
# 2                                    False                        False
# 3                                    False                        False
# 4                                    False                        False
# ..                                     ...                          ...
# 618                                  False                        False
# 619                                  False                        False
# 620                                  False                        False
# 621                                  False                        False
# 622                                  False                        False
#
#      paymentMethodType_bitcoin  paymentMethodType_card  \
# 0                        False                    True
# 1                         True                   False
# 2                        False                    True
# 3                        False                    True
# 4                        False                    True
# ..                         ...                     ...
# 618                      False                   False
# 619                      False                   False
# 620                      False                   False
# 621                      False                   False
# 622                      False                   False
#
#      paymentMethodType_paypal  paymentMethodProvider_American Express  \
# 0                       False                                   False
# 1                       False                                   False
# 2                       False                                   False
# 3                       False                                   False
# 4                       False                                   False
# ..                        ...                                     ...
# 618                     False                                   False
# 619                     False                                   False
# 620                     False                                   False
# 621                     False                                   False
# 622                     False                                   False
#
#      paymentMethodProvider_Diners Club / Carte Blanche  ...  \
# 0                                                False  ...
# 1                                                False  ...
# 2                                                False  ...
# 3                                                 True  ...
# 4                                                False  ...
# ..                                                 ...  ...
# 618                                              False  ...
# 619                                              False  ...
# 620                                              False  ...
# 621                                              False  ...
# 622                                              False  ...
#
#      emailProvider_gmail  emailProvider_hotmail  emailProvider_other  \
# 0                  False                  False                False
# 1                  False                  False                False
# 2                  False                  False                False
# 3                  False                  False                False
# 4                  False                  False                 True
# ..                   ...                    ...                  ...
# 618                False                  False                False
# 619                False                  False                False
# 620                False                  False                False
# 621                False                  False                False
# 622                False                  False                False
#
#      emailProvider_weird  emailProvider_yahoo  \
# 0                  False                 True
# 1                  False                 True
# 2                  False                 True
# 3                  False                 True
# 4                  False                False
# ..                   ...                  ...
# 618                 True                False
# 619                 True                False
# 620                 True                False
# 621                 True                False
# 622                 True                False
#
#      customerIPAddressSimplified_digits_and_letters  \
# 0                                             False
# 1                                             False
# 2                                              True
# 3                                              True
# 4                                             False
# ..                                              ...
# 618                                           False
# 619                                           False
# 620                                           False
# 621                                           False
# 622                                           False
#
#      customerIPAddressSimplified_only_numeric_digits  sameCity_no  \
# 0                                               True        False
# 1                                               True         True
# 2                                              False         True
# 3                                              False         True
# 4                                               True         True
# ..                                               ...          ...
# 618                                             True        False
# 619                                             True        False
# 620                                             True        False
# 621                                             True        False
# 622                                             True        False
#
#      sameCity_unknown  sameCity_yes
# 0               False          True
# 1               False         False
# 2               False         False
# 3               False         False
# 4               False         False
# ..                ...           ...
# 618              True         False
# 619              True         False
# 620              True         False
# 621              True         False
# 622              True         False
#
# [623 rows x 58 columns]

# %% [markdown]
# Eliminamos la variable objetivo de nuestro DataFrame para no guardarlo en nuestro archivo pickle, es decir, sin `fraudulent`.

# %%
data_ohe_without_fraudulent = data_ohe.drop(["fraudulent"], axis = 1)
data_ohe_without_fraudulent
# Out:
#      transactionFailed  paymentMethodRegistrationFailure_False  \
# 0                False                                   False
# 1                False                                   False
# 2                False                                    True
# 3                False                                    True
# 4                 True                                    True
# ..                 ...                                     ...
# 618               True                                   False
# 619               True                                   False
# 620              False                                   False
# 621              False                                   False
# 622              False                                   False
#
#      paymentMethodRegistrationFailure_True  paymentMethodType_apple pay  \
# 0                                     True                        False
# 1                                     True                        False
# 2                                    False                        False
# 3                                    False                        False
# 4                                    False                        False
# ..                                     ...                          ...
# 618                                  False                        False
# 619                                  False                        False
# 620                                  False                        False
# 621                                  False                        False
# 622                                  False                        False
#
#      paymentMethodType_bitcoin  paymentMethodType_card  \
# 0                        False                    True
# 1                         True                   False
# 2                        False                    True
# 3                        False                    True
# 4                        False                    True
# ..                         ...                     ...
# 618                      False                   False
# 619                      False                   False
# 620                      False                   False
# 621                      False                   False
# 622                      False                   False
#
#      paymentMethodType_paypal  paymentMethodProvider_American Express  \
# 0                       False                                   False
# 1                       False                                   False
# 2                       False                                   False
# 3                       False                                   False
# 4                       False                                   False
# ..                        ...                                     ...
# 618                     False                                   False
# 619                     False                                   False
# 620                     False                                   False
# 621                     False                                   False
# 622                     False                                   False
#
#      paymentMethodProvider_Diners Club / Carte Blanche  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                 True
# 4                                                False
# ..                                                 ...
# 618                                              False
# 619                                              False
# 620                                              False
# 621                                              False
# 622                                              False
#
#      paymentMethodProvider_Discover  ...  emailProvider_gmail  \
# 0                             False  ...                False
# 1                             False  ...                False
# 2                             False  ...                False
# 3                             False  ...                False
# 4                             False  ...                False
# ..                              ...  ...                  ...
# 618                           False  ...                False
# 619                           False  ...                False
# 620                           False  ...                False
# 621                           False  ...                False
# 622                           False  ...                False
#
#      emailProvider_hotmail  emailProvider_other  emailProvider_weird  \
# 0                    False                False                False
# 1                    False                False                False
# 2                    False                False                False
# 3                    False                False                False
# 4                    False                 True                False
# ..                     ...                  ...                  ...
# 618                  False                False                 True
# 619                  False                False                 True
# 620                  False                False                 True
# 621                  False                False                 True
# 622                  False                False                 True
#
#      emailProvider_yahoo  customerIPAddressSimplified_digits_and_letters  \
# 0                   True                                           False
# 1                   True                                           False
# 2                   True                                            True
# 3                   True                                            True
# 4                  False                                           False
# ..                   ...                                             ...
# 618                False                                           False
# 619                False                                           False
# 620                False                                           False
# 621                False                                           False
# 622                False                                           False
#
#      customerIPAddressSimplified_only_numeric_digits  sameCity_no  \
# 0                                               True        False
# 1                                               True         True
# 2                                              False         True
# 3                                              False         True
# 4                                               True         True
# ..                                               ...          ...
# 618                                             True        False
# 619                                             True        False
# 620                                             True        False
# 621                                             True        False
# 622                                             True        False
#
#      sameCity_unknown  sameCity_yes
# 0               False          True
# 1               False         False
# 2               False         False
# 3               False         False
# 4               False         False
# ..                ...           ...
# 618              True         False
# 619              True         False
# 620              True         False
# 621              True         False
# 622              True         False
#
# [623 rows x 57 columns]

# %% [markdown]
# ### 4.1 - Guardar ohe categories

# %%
with open("../ohe_categories_without_fraudulent.pickle", "wb") as handle:
    pickle.dump(data_ohe_without_fraudulent.columns, handle, protocol = pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## 5- Guardar dataset

# %%
filename = "../datasets/processed_data/ohe_customer_dataset.csv"
data_ohe.to_csv(filename, index = False)
